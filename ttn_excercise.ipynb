# %% [markdown]
# <a href="https://colab.research.google.com/github/Sairabanu32/project1/blob/main/ttn_excercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hi")
+from google.colab import drive
drive.mount('')
# Out:
# hi

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv("/content/drive/MyDrive/TTD Intern/Business-price-indexes-december-2025-quarter-csv.csv")
# Out:
# /tmp/ipykernel_11766/2677694432.py:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("/content/drive/MyDrive/TTD Intern/Business-price-indexes-december-2025-quarter-csv.csv")

# %%
df
# Out:
#       Series_reference   Period   Data_value STATUS  UNITS  \
# 0            CEPQ.S611  1989.12   456.670842  FINAL  Index
# 1            CEPQ.S611  1990.03   458.954197  FINAL  Index
# 2            CEPQ.S611  1990.06   466.717601  FINAL  Index
# 3            CEPQ.S611  1990.09   462.607563  FINAL  Index
# 4            CEPQ.S611  1990.12   467.174272  FINAL  Index
# ...                ...      ...          ...    ...    ...
# 81541   PPIQ.SQURS2110  2024.12  1742.000000  FINAL  Index
# 81542   PPIQ.SQURS2110  2025.03  1813.000000  FINAL  Index
# 81543   PPIQ.SQURS2110  2025.06  1815.000000  FINAL  Index
# 81544   PPIQ.SQURS2110  2025.09  1848.000000  FINAL  Index
# 81545   PPIQ.SQURS2110  2025.12  1921.000000  FINAL  Index
#
#                                Subject  \
# 0      Capital Goods Price Index - CEP
# 1      Capital Goods Price Index - CEP
# 2      Capital Goods Price Index - CEP
# 3      Capital Goods Price Index - CEP
# 4      Capital Goods Price Index - CEP
# ...

# %%
df.head(10)
# Out:
#   Series_reference   Period  Data_value STATUS  UNITS  \
# 0        CEPQ.S611  1989.12  456.670842  FINAL  Index
# 1        CEPQ.S611  1990.03  458.954197  FINAL  Index
# 2        CEPQ.S611  1990.06  466.717601  FINAL  Index
# 3        CEPQ.S611  1990.09  462.607563  FINAL  Index
# 4        CEPQ.S611  1990.12  467.174272  FINAL  Index
# 5        CEPQ.S611  1991.03  471.284309  FINAL  Index
# 6        CEPQ.S611  1991.06  474.024334  FINAL  Index
# 7        CEPQ.S611  1991.09  474.937676  FINAL  Index
# 8        CEPQ.S611  1991.12  478.134372  FINAL  Index
# 9        CEPQ.S611  1992.03  483.157751  FINAL  Index
#
#                            Subject  \
# 0  Capital Goods Price Index - CEP
# 1  Capital Goods Price Index - CEP
# 2  Capital Goods Price Index - CEP
# 3  Capital Goods Price Index - CEP
# 4  Capital Goods Price Index - CEP
# 5  Capital Goods Price Index - CEP
# 6  Capital Goods Price Index - CEP
# 7  Capital Goods Price Index - CEP
# 8  Capital Goods Price Index - CEP
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81546 entries, 0 to 81545
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Series_reference  81546 non-null  object
#  1   Period            81546 non-null  float64
#  2   Data_value        81146 non-null  float64
#  3   STATUS            81546 non-null  object
#  4   UNITS             81546 non-null  object
#  5   Subject           81546 non-null  object
#  6   Group             81546 non-null  object
#  7   Series_title_1    81546 non-null  object
#  8   Series_title_2    1047 non-null   object
#  9   Series_title_3    0 non-null      float64
#  10  Series_title_4    0 non-null      float64
#  11  Series_title_5    0 non-null      float64
# dtypes: float64(5), object(7)
# memory usage: 7.5+ MB

# %%
df.describe()
# Out:
#              Period    Data_value  Series_title_3  Series_title_4  \
# count  81546.000000  81146.000000             0.0             0.0
# mean    2010.061530    978.645811             NaN             NaN
# std       10.565156    347.992681             NaN             NaN
# min     1977.120000     -5.800000             NaN             NaN
# 25%     2002.060000    765.562679             NaN             NaN
# 50%     2012.060000   1000.000000             NaN             NaN
# 75%     2019.030000   1141.000000             NaN             NaN
# max     2025.120000   5239.000000             NaN             NaN
#
#        Series_title_5
# count             0.0
# mean              NaN
# std               NaN
# min               NaN
# 25%               NaN
# 50%               NaN
# 75%               NaN
# max               NaN

# %%
df.shape
# Out:
# (81546, 12)

# %%
df.columns
# Out:
# Index(['Series_reference', 'Period', 'Data_value', 'STATUS', 'UNITS',
#        'Subject', 'Group', 'Series_title_1', 'Series_title_2',
#        'Series_title_3', 'Series_title_4', 'Series_title_5'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Series_reference     object
# Period              float64
# Data_value          float64
# STATUS               object
# UNITS                object
# Subject              object
# Group                object
# Series_title_1       object
# Series_title_2       object
# Series_title_3      float64
# Series_title_4      float64
# Series_title_5      float64
# dtype: object

# %%
df.value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df.isnull().sum()
# Out:
# Series_reference        0
# Period                  0
# Data_value            400
# STATUS                  0
# UNITS                   0
# Subject                 0
# Group                   0
# Series_title_1          0
# Series_title_2      80499
# Series_title_3      81546
# Series_title_4      81546
# Series_title_5      81546
# dtype: int64

# %%
print(df.groupby)
# Out:
# <bound method DataFrame.groupby of       Series_reference   Period   Data_value STATUS  UNITS  \
# 0            CEPQ.S611  1989.12   456.670842  FINAL  Index
# 1            CEPQ.S611  1990.03   458.954197  FINAL  Index
# 2            CEPQ.S611  1990.06   466.717601  FINAL  Index
# 3            CEPQ.S611  1990.09   462.607563  FINAL  Index
# 4            CEPQ.S611  1990.12   467.174272  FINAL  Index
# ...                ...      ...          ...    ...    ...
# 81541   PPIQ.SQURS2110  2024.12  1742.000000  FINAL  Index
# 81542   PPIQ.SQURS2110  2025.03  1813.000000  FINAL  Index
# 81543   PPIQ.SQURS2110  2025.06  1815.000000  FINAL  Index
# 81544   PPIQ.SQURS2110  2025.09  1848.000000  FINAL  Index
# 81545   PPIQ.SQURS2110  2025.12  1921.000000  FINAL  Index
#
#                                Subject  \
# 0      Capital Goods Price Index - CEP
# 1      Capital Goods Price Index - CEP
# 2      Capital Goods Price Index - CEP
# 3      Capital Goods Price Index - CEP
# ...

# %%
print(df.sort_values)
# Out:
# <bound method DataFrame.sort_values of       Series_reference   Period   Data_value STATUS  UNITS  \
# 0            CEPQ.S611  1989.12   456.670842  FINAL  Index
# 1            CEPQ.S611  1990.03   458.954197  FINAL  Index
# 2            CEPQ.S611  1990.06   466.717601  FINAL  Index
# 3            CEPQ.S611  1990.09   462.607563  FINAL  Index
# 4            CEPQ.S611  1990.12   467.174272  FINAL  Index
# ...                ...      ...          ...    ...    ...
# 81541   PPIQ.SQURS2110  2024.12  1742.000000  FINAL  Index
# 81542   PPIQ.SQURS2110  2025.03  1813.000000  FINAL  Index
# 81543   PPIQ.SQURS2110  2025.06  1815.000000  FINAL  Index
# 81544   PPIQ.SQURS2110  2025.09  1848.000000  FINAL  Index
# 81545   PPIQ.SQURS2110  2025.12  1921.000000  FINAL  Index
#
#                                Subject  \
# 0      Capital Goods Price Index - CEP
# 1      Capital Goods Price Index - CEP
# 2      Capital Goods Price Index - CEP
# 3      Capital Goods Price Index - CEP
# ...

# %%
print(dir(df))
# Out:
# ['Data_value', 'Group', 'Period', 'STATUS', 'Series_reference', 'Series_title_1', 'Series_title_2', 'Series_title_3', 'Series_title_4', 'Series_title_5', 'Subject', 'T', 'UNITS', '_AXIS_LEN', '_AXIS_ORDERS', '_AXIS_TO_AXIS_NUMBER', '_HANDLED_TYPES', '__abs__', '__add__', '__and__', '__annotations__', '__array__', '__array_priority__', '__array_ufunc__', '__arrow_c_stream__', '__bool__', '__class__', '__contains__', '__copy__', '__dataframe__', '__dataframe_consortium_standard__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__divmod__', '__doc__', '__eq__', '__finalize__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__iand__', '__ifloordiv__', '__imod__', '__imul__', '__init__', '__init_subclass__', '__invert__', '__ior__', '__ipow__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__
# ...

# %%
df = df.drop('Group', axis=1)
display(df.head())
# Out:
#   Series_reference   Period  Data_value STATUS  UNITS  \
# 0        CEPQ.S611  1989.12  456.670842  FINAL  Index
# 1        CEPQ.S611  1990.03  458.954197  FINAL  Index
# 2        CEPQ.S611  1990.06  466.717601  FINAL  Index
# 3        CEPQ.S611  1990.09  462.607563  FINAL  Index
# 4        CEPQ.S611  1990.12  467.174272  FINAL  Index
#
#                            Subject Series_title_1 Series_title_2  \
# 0  Capital Goods Price Index - CEP     All Groups            NaN
# 1  Capital Goods Price Index - CEP     All Groups            NaN
# 2  Capital Goods Price Index - CEP     All Groups            NaN
# 3  Capital Goods Price Index - CEP     All Groups            NaN
# 4  Capital Goods Price Index - CEP     All Groups            NaN
#
#    Series_title_3  Series_title_4  Series_title_5
# 0             NaN             NaN             NaN
# 1             NaN             NaN             NaN
# 2             NaN             NaN             NaN
# ...

# %%
print(df.isnull().sum())
# Out:
# Series_reference        0
# Period                  0
# Data_value            400
# STATUS                  0
# UNITS                   0
# Subject                 0
# Series_title_1          0
# Series_title_2      80499
# Series_title_3      81546
# Series_title_4      81546
# Series_title_5      81546
# dtype: int64

# %%
df=df.dropna()
print(df.isnull().sum())
# Out:
# Series_reference    0
# Period              0
# Data_value          0
# STATUS              0
# UNITS               0
# Subject             0
# Series_title_1      0
# Series_title_2      0
# Series_title_3      0
# Series_title_4      0
# Series_title_5      0
# dtype: int64
